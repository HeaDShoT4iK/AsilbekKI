# %% [markdown]
# <a href="https://colab.research.google.com/github/HeaDShoT4iK/AsilbekKI/blob/main/5_amaliy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First, you need to upload your CSV file to Colab. You can do this by clicking the 'Files' icon on the left sidebar, then clicking the 'Upload to session storage' icon. Once uploaded, provide the filename below.

# %%
import pandas as pd
from google.colab import files
import io

# Use this code to prompt for upload
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  csv_file_name = fn # Assign the uploaded file name

try:
    df = pd.read_csv(csv_file_name)
    print(f"'{csv_file_name}' loaded successfully. Displaying first 5 rows:")
    display(df.head())
except FileNotFoundError:
    print(f"Error: '{csv_file_name}' not found. Please ensure the file is uploaded and the name is correct.")
except Exception as e:
    print(f"An error occurred while reading the CSV file: {e}")
# Out:
#      <input type="file" id="files-4708bebc-48cc-4fcc-99a1-27ca1b32a1ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4708bebc-48cc-4fcc-99a1-27ca1b32a1ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# After loading the data, we can proceed with Multiple Linear Regression (MLR). Before performing MLR, we need to identify the target variable and features. Please specify which column is your target variable (dependent variable) and which columns are your features (independent variables).
